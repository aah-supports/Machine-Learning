# %% [markdown]
# # TP : Descente de gradient à la main
#
# ## Objectif
#
# Comprendre comment on fait bouger un poids `w` à partir d'une fonction de coût simple.
#
# On travaille ici avec un cas volontairement réduit : une seule variable `x`, une seule observation, et un seul poids.

# %% [markdown]
# ## 1. Le modèle
#
# On prend :
#
# ```text
# ŷ = w x
# ```
#
# avec une observation :
#
# | x | y |
# | -- | -- |
# | 50 | 100 |
#
# La fonction de coût est :
#
# ```text
# J(w) = (100 - 50w)^2
# ```

# %%
x = 50
y = 100

def cost(w):
    return (y - x * w) ** 2

weights = [0, 1, 1.5, 2, 2.5]

# %% [markdown]
# ## 2. Calculer la courbe du coût
#
# 1. Compléter la boucle pour afficher `w` et `J(w)`.
# 2. Repérer la valeur qui minimise l'erreur.
# 3. Vérifier que la courbe ressemble à une parabole.

# %%
# TODO : afficher le coût pour chaque valeur de w
# for w in weights:
#     print(w, cost(w))

# %% [markdown]
# ## 3. Calculer la pente
#
# La dérivée de la fonction de coût est :
#
# ```text
# J'(w) = -100(100 - 50w)
# ```
#
# 1. Compléter la fonction `gradient`.
# 2. Calculer `J'(1)`.
# 3. Dire si le poids doit augmenter ou diminuer.

# %%
# TODO : compléter la dérivée
# def gradient(w):
#     ...

# print(gradient(1))

# %% [markdown]
# ## 4. Mettre à jour le poids
#
# On applique :
#
# ```text
# w_nouveau = w - η J'(w)
# ```
#
# avec :
#
# ```text
# η = 0.0001
# ```
#
# Compléter la mise à jour pour passer de `w = 1` à `w_nouveau`.

# %%
# TODO : calculer la nouvelle valeur de w
# eta = 0.0001
# w = 1
# w_new = ...
# print(w_new)

# %% [markdown]
# ## 5. Faire plusieurs itérations
#
# On recommence plusieurs fois la même règle pour se rapprocher du minimum.
#
# Compléter la boucle pour observer la convergence.

# %%
# TODO : faire plusieurs mises à jour
# w = 1
# for _ in range(5):
#     w = ...
#     print(w)

# %% [markdown]
# ## 6. Question de synthèse
#
# Explique avec tes mots :
#
# - ce que représente `J(w)` ;
# - pourquoi on regarde la dérivée ;
# - pourquoi on avance dans le sens opposé à la pente ;
# - pourquoi ce mécanisme est utile pour les réseaux de neurones.
